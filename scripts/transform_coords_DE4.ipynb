# %% [markdown]
# Brandenburg (DE4):
#
# Transform coordinates from EPSG:32633 to EPSG:3035

# %%
from pyproj import Transformer
import pandas as pd
import numpy as np

# %%
DE4_meta_data = pd.read_csv('../output_data/raw_metadata/DE4_raw_metadata.csv')

# %%
DE4_meta_data
# Out:
#                                      Name      ID    Parameter Einheit  \
# 0      Alt Ruppin, Schleuse OP.Q.TagWerte  165666   Durchfluss    m³/s
# 1    Altlandsberg 2, Walkmühle.Q.TagWerte  278150   Durchfluss    m³/s
# 2           Babelsberg-Drewitz.Q.TagWerte  166379   Durchfluss    m³/s
# 3              Bad Liebenwerda.Q.TagWerte  166369   Durchfluss    m³/s
# 4                 Bad Wilsnack.Q.TagWerte  165980   Durchfluss    m³/s
# ..                                    ...     ...          ...     ...
# 377              Wünsdorf 1 UP.W.TagWerte  301037  Wasserstand      cm
# 378              Wünsdorf 2 OP.W.TagWerte  301044  Wasserstand      cm
# 379                   Wünsdorf.W.TagWerte  301055  Wasserstand      cm
# 380     Zeuthen, Straßenbrücke.W.TagWerte  301061  Wasserstand      cm
# 381                   Zschorno.W.TagWerte  277775  Wasserstand      cm
#
#      Anzahl Messwerte        Messwerte von        Messwerte bis  \
# 0               15327  01.11.1980 00:00:00  18.10.2022 00:00:00
# 1               11990  01.11.1987 00:00:00  31.08.2022 00:00:00
# 2               24824  01.11.1954 00:00:00  18.10.2022 00:00:00
# 3               23364  01.11.1960 00:00:00  19.10.2022 00:00:00
# 4               16056  01.11.1975 00:00:00  16.10.2022 00:00:00
# ..                ...                  ...                  ...
# 377             14184  01.11.1983 00:00:00  31.08.2022 00:00:00
# 378             19191  01.11.1969 00:00:00  31.08.2022 00:00:00
# 379             14183  01.11.1983 00:00:00  31.08.2022 00:00:00
# 380             17123  01.11.1975 00:00:00  17.10.2022 00:00:00
# 381             16420  01.11.1977 00:00:00  17.10.2022 00:00:00
#
#            Name vom Messort/ Messgebiet                  Pegelname  \
# 0      Alt Ruppin, Schleuse OP, 5891200    Alt Ruppin, Schleuse OP
# 1    Altlandsberg 2, Walkmühle, 5861002  Altlandsberg 2, Walkmühle
# 2           Babelsberg-Drewitz, 5871600         Babelsberg-Drewitz
# 3              Bad Liebenwerda, 5530500            Bad Liebenwerda
# 4                 Bad Wilsnack, 5930500               Bad Wilsnack
# ..                                  ...                        ...
# 377              Wünsdorf 1 UP, 5865501              Wünsdorf 1 UP
# 378              Wünsdorf 2 OP, 5865600              Wünsdorf 2 OP
# 379                   Wünsdorf, 5865502                   Wünsdorf
# 380     Zeuthen, Straßenbrücke, 5865900     Zeuthen, Straßenbrücke
# 381                   Zschorno, 6650100                   Zschorno
#
#                         Gewaesser  ... Messstellennummer      CRS    Ost/RW  \
# 0    Rhin (Ruppiner Wasserstraße)  ...           5891200  UTM 33N  354590.0
# 1         Erpe/Neuenhagener Fließ  ...           5861002  UTM 33N  413345.0
# 2                           Nuthe  ...           5871600  UTM 33N  371737.0
# 3                 Schwarze Elster  ...           5530500  UTM 33N  388602.0
# 4                        Karthane  ...           5930500  UTM 33N  294280.0
# ..                            ...  ...               ...      ...       ...
# 377              Wünsdorfer Kanal  ...           5865501  UTM 33N  393811.0
# 378                  Neuer Graben  ...           5865600  UTM 33N  394693.0
# 379                    Luchgraben  ...           5865502  UTM 33N  393821.0
# 380          Selchower Flutgraben  ...           5865900  UTM 33N  406492.0
# 381        Föhrenfließ/Lachgraben  ...           6650100  UTM 33N  479160.0
#
#        Nord/HW      W_seit       W_bis      Q_seit               station_name  \
# 0    5869955.0         NaN         NaN         NaN    Alt Ruppin, Schleuse OP
# 1    5825130.0  24.08.1987     aktuell  01.11.1987  Altlandsberg 2, Walkmühle
# 2    5803058.0         NaN         NaN         NaN         Babelsberg-Drewitz
# 3    5708769.0  01.12.1887     aktuell  01.11.1920            Bad Liebenwerda
# 4    5871815.0         NaN         NaN         NaN               Bad Wilsnack
# ..         ...         ...         ...         ...                        ...
# 377  5778777.0         NaN  17.05.1983  17.05.1983              Wünsdorf 1 UP
# 378  5779961.0  01.08.1969     aktuell  01.08.1969              Wünsdorf 2 OP
# 379  5778750.0  17.05.1983     aktuell  17.05.1983                   Wünsdorf
# 380  5801049.0  09.06.1975     aktuell  01.11.1975     Zeuthen, Straßenbrücke
# 381  5714011.0  01.11.1977     aktuell  01.11.1977                   Zschorno
#
#     CATCHMENT_SIZE BODY_RESPONSIBLE
# 0       533,24 km²  LfU Brandenburg
# 1       118,21 km²  LfU Brandenburg
# 2      1792,07 km²  LfU Brandenburg
# 3      3154,03 km²  LfU Brandenburg
# 4       284,62 km²  LfU Brandenburg
# ..             ...              ...
# 377      47,31 km²  LfU Brandenburg
# 378       0,04 km²  LfU Brandenburg
# 379      47,31 km²  LfU Brandenburg
# 380      76,01 km²  LfU Brandenburg
# 381      75,62 km²  LfU Brandenburg
#
# [382 rows x 29 columns]

# %%
transformer = Transformer.from_crs("EPSG:32633", "EPSG:3035", always_xy=True)

# %%
# transform x y coords to EPSG:3035
x_transformed = []
y_transformed = []

for i in range(np.shape(DE4_meta_data)[0]):
    x = DE4_meta_data['Ost/RW'][i]
    y = DE4_meta_data['Nord/HW'][i]

    x_transformed.append(transformer.transform(x, y)[0])
    y_transformed.append(transformer.transform(x, y)[1])

# %%
# remove string form area column and generate an area array
area = []

for i in range(np.shape(DE4_meta_data)[0]):
    
    if pd.isna(DE4_meta_data['CATCHMENT_SIZE'])[i]:
        area.append(np.nan)
    
    else:
        area_ob = DE4_meta_data['CATCHMENT_SIZE'][i].replace(',', '.')
        area.append(float(area_ob.replace(' km²', '')))

# %%
BR_Location = pd.DataFrame({'ID':DE4_meta_data['ID'], 'area':area, 'X':x_transformed, 'Y':y_transformed})
BR_Location
# Out:
#          ID     area             X             Y
# 0    165666   533.24  4.511477e+06  3.320481e+06
# 1    278150   118.21  4.573204e+06  3.279801e+06
# 2    166379  1792.07  4.533215e+06  3.254909e+06
# 3    166369  3154.03  4.556514e+06  3.161963e+06
# 4    165980   284.62  4.451184e+06  3.318162e+06
# ..      ...      ...           ...           ...
# 377  301037    47.31  4.556911e+06  3.232194e+06
# 378  301044     0.04  4.557710e+06  3.233436e+06
# 379  301055    47.31  4.556923e+06  3.232167e+06
# 380  301061    76.01  4.568029e+06  3.255294e+06
# 381  277775    75.62  4.646510e+06  3.173394e+06
#
# [382 rows x 4 columns]

# %%
BR_Location.to_csv('../output_data/locations/DE4_Locations.csv', index=False)
